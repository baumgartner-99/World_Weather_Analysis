# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | padang
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | tupiza
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | bambanglipuro
# Processing Record 8 of Set 1 | karwar
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | broken hill
# Processing Record 12 of Set 1 | ancud
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | sur
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | tongren
# Processing Record 18 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 1 | tegal
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | berdsk
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | ahipara
# Processing Record 25 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 1 | luanda
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | boa vista
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | walvis bay
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | adrar
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | fratautii noi
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | kahului
# Processing Record 41 of Set 1 | whitehorse
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | kudahuvadhoo
# Processing Record 44 of Set 1 | val
# Processing Record 45 of Set 1 | talnakh
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | nouadhibou
# Processing Record 49 of Set 1 | faya
# Processing Record 50 of Set 1 | farah
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | esperance
# Processing Record 4 of Set 2 | otradnoye
# Processing Record 5 of Set 2 | samarai
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | beringovskiy
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | oranjestad
# Processing Record 11 of Set 2 | takoradi
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | port hardy
# Processing Record 14 of Set 2 | lagos
# Processing Record 15 of Set 2 | dali
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | balkanabat
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | yumen
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | mantua
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | wakkanai
# Processing Record 25 of Set 2 | lac du bonnet
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | arak
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | deputatskiy
# Processing Record 31 of Set 2 | tapikan
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | waipawa
# Processing Record 34 of Set 2 | touros
# Processing Record 35 of Set 2 | poum
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 2 | santa isabel do rio negro
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | ormond beach
# Processing Record 43 of Set 2 | veraval
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | labuhan
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | kununurra
# Processing Record 48 of Set 2 | goderich
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | silver city
# Processing Record 1 of Set 3 | yulara
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | oussouye
# Processing Record 6 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 3 | mogadishu
# Processing Record 8 of Set 3 | flinders
# Processing Record 9 of Set 3 | mugumu
# Processing Record 10 of Set 3 | pocoes
# Processing Record 11 of Set 3 | luganville
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | tutoia
# Processing Record 15 of Set 3 | osypenko
# Processing Record 16 of Set 3 | batagay-alyta
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | kyzyl-suu
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | nikolayevsk-na-amure
# Processing Record 22 of Set 3 | aklavik
# Processing Record 23 of Set 3 | kenai
# Processing Record 24 of Set 3 | mount isa
# Processing Record 25 of Set 3 | honningsvag
# Processing Record 26 of Set 3 | reconquista
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | hermanus
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | clearwater
# Processing Record 31 of Set 3 | sao joao da barra
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | bend
# Processing Record 34 of Set 3 | bereda
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | severo-yeniseyskiy
# Processing Record 38 of Set 3 | prieska
# Processing Record 39 of Set 3 | ustka
# Processing Record 40 of Set 3 | sereflikochisar
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | bilma
# Processing Record 43 of Set 3 | andenes
# Processing Record 44 of Set 3 | chenghai
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | klyuchi
# Processing Record 47 of Set 3 | cabatuan
# Processing Record 48 of Set 3 | vestmannaeyjar
# Processing Record 49 of Set 3 | gornoye loo
# Processing Record 50 of Set 3 | havre-saint-pierre
# Processing Record 1 of Set 4 | beloha
# Processing Record 2 of Set 4 | akom
# Processing Record 3 of Set 4 | assai
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | tilichiki
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | waingapu
# Processing Record 9 of Set 4 | koutiala
# Processing Record 10 of Set 4 | lillooet
# Processing Record 11 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | cocal
# Processing Record 14 of Set 4 | mae sai
# Processing Record 15 of Set 4 | plettenberg bay
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | neyshabur
# Processing Record 18 of Set 4 | sungairaya
# Processing Record 19 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 4 | port elizabeth
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | cubuk
# Processing Record 23 of Set 4 | khislavichi
# Processing Record 24 of Set 4 | mpika
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | vanavara
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | boundiali
# Processing Record 32 of Set 4 | a
# City not found. Skipping...
# Processing Record 33 of Set 4 | rawson
# Processing Record 34 of Set 4 | morros
# Processing Record 35 of Set 4 | shelburne
# Processing Record 36 of Set 4 | vilyuysk
# Processing Record 37 of Set 4 | saint-francois
# Processing Record 38 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 4 | teguldet
# Processing Record 40 of Set 4 | bukama
# Processing Record 41 of Set 4 | mandera
# Processing Record 42 of Set 4 | constitucion
# Processing Record 43 of Set 4 | krasnoselkup
# Processing Record 44 of Set 4 | iralaya
# Processing Record 45 of Set 4 | sistranda
# Processing Record 46 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 4 | pokhara
# Processing Record 48 of Set 4 | san francisco
# Processing Record 49 of Set 4 | dalby
# Processing Record 50 of Set 4 | upata
# Processing Record 1 of Set 5 | kaduna
# Processing Record 2 of Set 5 | sao gabriel da cachoeira
# Processing Record 3 of Set 5 | iranshahr
# Processing Record 4 of Set 5 | parrita
# Processing Record 5 of Set 5 | nagato
# Processing Record 6 of Set 5 | bataipora
# Processing Record 7 of Set 5 | havoysund
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | saanen
# Processing Record 10 of Set 5 | gariadhar
# Processing Record 11 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | necochea
# Processing Record 14 of Set 5 | tianjin
# Processing Record 15 of Set 5 | pangody
# Processing Record 16 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 5 | arlit
# Processing Record 18 of Set 5 | hirara
# Processing Record 19 of Set 5 | lentekhi
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | altagracia de orituco
# Processing Record 22 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | cockburn town
# Processing Record 24 of Set 5 | neman
# Processing Record 25 of Set 5 | verkhnevilyuysk
# Processing Record 26 of Set 5 | east london
# Processing Record 27 of Set 5 | kurmanayevka
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | christchurch
# Processing Record 30 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 31 of Set 5 | nemuro
# Processing Record 32 of Set 5 | seoul
# Processing Record 33 of Set 5 | aleksandrov gay
# Processing Record 34 of Set 5 | neftcala
# Processing Record 35 of Set 5 | shalinskoye
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | novobirilyussy
# Processing Record 38 of Set 5 | hope
# Processing Record 39 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 5 | pimenta bueno
# Processing Record 42 of Set 5 | indiana
# Processing Record 43 of Set 5 | mbandaka
# Processing Record 44 of Set 5 | baruun-urt
# Processing Record 45 of Set 5 | broome
# Processing Record 46 of Set 5 | tanete
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | kuningan
# Processing Record 50 of Set 5 | bredasdorp
# Processing Record 1 of Set 6 | orvieto
# Processing Record 2 of Set 6 | halifax
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | rockport
# Processing Record 5 of Set 6 | zapolyarnyy
# Processing Record 6 of Set 6 | guiratinga
# Processing Record 7 of Set 6 | karratha
# Processing Record 8 of Set 6 | ambulu
# Processing Record 9 of Set 6 | moiyabana
# City not found. Skipping...
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | sioux lookout
# Processing Record 12 of Set 6 | kattivakkam
# Processing Record 13 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 6 | isangel
# Processing Record 15 of Set 6 | lake havasu city
# Processing Record 16 of Set 6 | yazoo city
# Processing Record 17 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 6 | berlevag
# Processing Record 19 of Set 6 | camopi
# Processing Record 20 of Set 6 | offa
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | dzilam gonzalez
# Processing Record 23 of Set 6 | hvide sande
# Processing Record 24 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 6 | vardo
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 6 | avera
# Processing Record 29 of Set 6 | daigo
# Processing Record 30 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 6 | kesennuma
# City not found. Skipping...
# Processing Record 32 of Set 6 | asyut
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 6 | kloulklubed
# Processing Record 36 of Set 6 | erenhot
# Processing Record 37 of Set 6 | mount gambier
# Processing Record 38 of Set 6 | solenzo
# Processing Record 39 of Set 6 | henties bay
# Processing Record 40 of Set 6 | tiksi
# Processing Record 41 of Set 6 | jalu
# Processing Record 42 of Set 6 | rio grande
# Processing Record 43 of Set 6 | remedios
# Processing Record 44 of Set 6 | oranzherei
# Processing Record 45 of Set 6 | vostok
# Processing Record 46 of Set 6 | martaban
# Processing Record 47 of Set 6 | wheatley
# Processing Record 48 of Set 6 | amahai
# Processing Record 49 of Set 6 | guerrero negro
# Processing Record 50 of Set 6 | manali
# Processing Record 1 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 7 | lancaster
# Processing Record 3 of Set 7 | hofn
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | zhigansk
# Processing Record 6 of Set 7 | ambon
# Processing Record 7 of Set 7 | tuburan
# Processing Record 8 of Set 7 | wasilla
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | salalah
# Processing Record 11 of Set 7 | cepu
# Processing Record 12 of Set 7 | oron
# Processing Record 13 of Set 7 | wanning
# Processing Record 14 of Set 7 | bandarbeyla
# Processing Record 15 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 16 of Set 7 | high rock
# Processing Record 17 of Set 7 | tessalit
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | ladario
# Processing Record 20 of Set 7 | pietrasanta
# Processing Record 21 of Set 7 | zhicheng
# Processing Record 22 of Set 7 | redmond
# Processing Record 23 of Set 7 | catamarca
# Processing Record 24 of Set 7 | paita
# Processing Record 25 of Set 7 | verkhoyansk
# Processing Record 26 of Set 7 | camacha
# Processing Record 27 of Set 7 | olga
# Processing Record 28 of Set 7 | san quintin
# Processing Record 29 of Set 7 | cidreira
# Processing Record 30 of Set 7 | klaipeda
# Processing Record 31 of Set 7 | dzhebariki-khaya
# Processing Record 32 of Set 7 | madimba
# Processing Record 33 of Set 7 | cottonwood
# Processing Record 34 of Set 7 | semnan
# Processing Record 35 of Set 7 | burnie
# Processing Record 36 of Set 7 | male
# Processing Record 37 of Set 7 | bilibino
# Processing Record 38 of Set 7 | san dona di piave
# Processing Record 39 of Set 7 | aljezur
# Processing Record 40 of Set 7 | killybegs
# Processing Record 41 of Set 7 | muromtsevo
# Processing Record 42 of Set 7 | umea
# Processing Record 43 of Set 7 | mehamn
# Processing Record 44 of Set 7 | kovdor
# Processing Record 45 of Set 7 | nicoya
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | takestan
# Processing Record 48 of Set 7 | taga
# Processing Record 49 of Set 7 | carnarvon
# Processing Record 50 of Set 7 | yar-sale
# Processing Record 1 of Set 8 | wampusirpi
# City not found. Skipping...
# Processing Record 2 of Set 8 | caravelas
# Processing Record 3 of Set 8 | souillac
# Processing Record 4 of Set 8 | aquiraz
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | wittmund
# Processing Record 7 of Set 8 | chokurdakh
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | chicama
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | mandalgovi
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | payson
# Processing Record 14 of Set 8 | vangaindrano
# Processing Record 15 of Set 8 | kimbe
# Processing Record 16 of Set 8 | nyurba
# Processing Record 17 of Set 8 | helong
# Processing Record 18 of Set 8 | thinadhoo
# Processing Record 19 of Set 8 | ponnani
# Processing Record 20 of Set 8 | piet retief
# Processing Record 21 of Set 8 | berdigestyakh
# Processing Record 22 of Set 8 | manglaur
# Processing Record 23 of Set 8 | abnub
# Processing Record 24 of Set 8 | shimoda
# Processing Record 25 of Set 8 | nurobod
# Processing Record 26 of Set 8 | uribia
# Processing Record 27 of Set 8 | yashkul
# Processing Record 28 of Set 8 | riviere-au-renard
# Processing Record 29 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 8 | vila franca do campo
# Processing Record 31 of Set 8 | marakkanam
# Processing Record 32 of Set 8 | puerto santander
# Processing Record 33 of Set 8 | kaniama
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | peniche
# Processing Record 36 of Set 8 | ilo
# Processing Record 37 of Set 8 | alofi
# Processing Record 38 of Set 8 | belyy yar
# Processing Record 39 of Set 8 | lorengau
# Processing Record 40 of Set 8 | sao mateus
# Processing Record 41 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 8 | abha
# Processing Record 43 of Set 8 | mareeba
# Processing Record 44 of Set 8 | conway
# Processing Record 45 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 46 of Set 8 | southbridge
# Processing Record 47 of Set 8 | lavrentiya
# Processing Record 48 of Set 8 | warmbad
# Processing Record 49 of Set 8 | mandiana
# Processing Record 50 of Set 8 | pitimbu
# Processing Record 1 of Set 9 | nome
# Processing Record 2 of Set 9 | puerto maldonado
# Processing Record 3 of Set 9 | patiya
# Processing Record 4 of Set 9 | xinxiang
# Processing Record 5 of Set 9 | maniitsoq
# Processing Record 6 of Set 9 | leningradskiy
# Processing Record 7 of Set 9 | kargasok
# Processing Record 8 of Set 9 | kambove
# Processing Record 9 of Set 9 | richards bay
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | lloydminster
# Processing Record 12 of Set 9 | nara
# Processing Record 13 of Set 9 | colombo
# Processing Record 14 of Set 9 | bonthe
# Processing Record 15 of Set 9 | yiyang
# Processing Record 16 of Set 9 | san juan
# Processing Record 17 of Set 9 | jumla
# Processing Record 18 of Set 9 | tombouctou
# Processing Record 19 of Set 9 | lasa
# Processing Record 20 of Set 9 | eureka
# Processing Record 21 of Set 9 | guarapari
# Processing Record 22 of Set 9 | saint-pierre
# Processing Record 23 of Set 9 | souris
# Processing Record 24 of Set 9 | zaragoza
# Processing Record 25 of Set 9 | port said
# Processing Record 26 of Set 9 | san lawrenz
# Processing Record 27 of Set 9 | hurricane
# Processing Record 28 of Set 9 | kaeo
# Processing Record 29 of Set 9 | puerto colombia
# Processing Record 30 of Set 9 | ayr
# Processing Record 31 of Set 9 | staryy nadym
# Processing Record 32 of Set 9 | lengshuitan
# Processing Record 33 of Set 9 | mirabad
# Processing Record 34 of Set 9 | catuday
# Processing Record 35 of Set 9 | manoel urbano
# Processing Record 36 of Set 9 | tyukhtet
# Processing Record 37 of Set 9 | majene
# Processing Record 38 of Set 9 | normandin
# Processing Record 39 of Set 9 | saint-augustin
# Processing Record 40 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 9 | indiaroba
# Processing Record 42 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 9 | sisimiut
# Processing Record 44 of Set 9 | mudyuga
# City not found. Skipping...
# Processing Record 45 of Set 9 | mocsa
# Processing Record 46 of Set 9 | riedlingen
# Processing Record 47 of Set 9 | solton
# Processing Record 48 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 9 | lebu
# Processing Record 50 of Set 9 | awjilah
# Processing Record 1 of Set 10 | ihosy
# Processing Record 2 of Set 10 | baijiantan
# Processing Record 3 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 4 of Set 10 | narsaq
# Processing Record 5 of Set 10 | shepsi
# Processing Record 6 of Set 10 | kaspiyskiy
# Processing Record 7 of Set 10 | san patricio
# Processing Record 8 of Set 10 | te anau
# Processing Record 9 of Set 10 | trincomalee
# Processing Record 10 of Set 10 | wattegama
# Processing Record 11 of Set 10 | aktash
# Processing Record 12 of Set 10 | pasni
# Processing Record 13 of Set 10 | ajdabiya
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | itacare
# Processing Record 16 of Set 10 | asfi
# Processing Record 17 of Set 10 | motihari
# Processing Record 18 of Set 10 | pilar do sul
# Processing Record 19 of Set 10 | nyuzen
# Processing Record 20 of Set 10 | north bend
# Processing Record 21 of Set 10 | matay
# Processing Record 22 of Set 10 | korla
# Processing Record 23 of Set 10 | pidhaytsi
# Processing Record 24 of Set 10 | vredendal
# Processing Record 25 of Set 10 | mackay
# Processing Record 26 of Set 10 | sambava
# Processing Record 27 of Set 10 | berikulskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | los llanos de aridane
# Processing Record 29 of Set 10 | umarkot
# Processing Record 30 of Set 10 | vila
# Processing Record 31 of Set 10 | wagar
# Processing Record 32 of Set 10 | naze
# Processing Record 33 of Set 10 | sangin
# Processing Record 34 of Set 10 | alyangula
# Processing Record 35 of Set 10 | aksehir
# Processing Record 36 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 10 | tiznit
# Processing Record 38 of Set 10 | zabid
# Processing Record 39 of Set 10 | severnyy
# Processing Record 40 of Set 10 | piacabucu
# Processing Record 41 of Set 10 | maceio
# Processing Record 42 of Set 10 | houston
# Processing Record 43 of Set 10 | olinda
# Processing Record 44 of Set 10 | pierre
# Processing Record 45 of Set 10 | eston
# Processing Record 46 of Set 10 | maracacume
# Processing Record 47 of Set 10 | shirokiy
# Processing Record 48 of Set 10 | mildura
# Processing Record 49 of Set 10 | sitka
# Processing Record 50 of Set 10 | bodden town
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | paamiut
# Processing Record 3 of Set 11 | quimper
# Processing Record 4 of Set 11 | kiruna
# Processing Record 5 of Set 11 | koulikoro
# Processing Record 6 of Set 11 | sakaiminato
# Processing Record 7 of Set 11 | jamsa
# Processing Record 8 of Set 11 | porto walter
# Processing Record 9 of Set 11 | camacari
# Processing Record 10 of Set 11 | victoria
# Processing Record 11 of Set 11 | piedras negras
# Processing Record 12 of Set 11 | polyarnyye zori
# Processing Record 13 of Set 11 | shubarkuduk
# Processing Record 14 of Set 11 | lodja
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | cabo san lucas
# Processing Record 17 of Set 11 | itamarandiba
# Processing Record 18 of Set 11 | washington
# Processing Record 19 of Set 11 | abrego
# Processing Record 20 of Set 11 | tsaratanana
# Processing Record 21 of Set 11 | kurilsk
# Processing Record 22 of Set 11 | winona
# Processing Record 23 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 11 | council bluffs
# Processing Record 25 of Set 11 | sosnogorsk
# Processing Record 26 of Set 11 | albert
# Processing Record 27 of Set 11 | huejuquilla el alto
# Processing Record 28 of Set 11 | garowe
# Processing Record 29 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | kristiinankaupunki
# Processing Record 31 of Set 11 | zhangjiakou
# Processing Record 32 of Set 11 | ca mau
# Processing Record 33 of Set 11 | friesach
# Processing Record 34 of Set 11 | oriximina
# Processing Record 35 of Set 11 | sokolka
# Processing Record 36 of Set 11 | chantada
# Processing Record 37 of Set 11 | pukhrayan
# Processing Record 38 of Set 11 | harper
# Processing Record 39 of Set 11 | elmina
# Processing Record 40 of Set 11 | dobroye
# Processing Record 41 of Set 11 | cairns
# Processing Record 42 of Set 11 | gao
# Processing Record 43 of Set 11 | son la
# Processing Record 44 of Set 11 | bouar
# Processing Record 45 of Set 11 | nantucket
# Processing Record 46 of Set 11 | hobyo
# Processing Record 47 of Set 11 | mayor pablo lagerenza
# Processing Record 48 of Set 11 | bathsheba
# Processing Record 49 of Set 11 | saveh
# Processing Record 50 of Set 11 | mitsamiouli
# Processing Record 1 of Set 12 | daru
# Processing Record 2 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 12 | tubuala
# Processing Record 4 of Set 12 | yarmouth
# Processing Record 5 of Set 12 | abiy adi
# City not found. Skipping...
# Processing Record 6 of Set 12 | agstafa
# City not found. Skipping...
# Processing Record 7 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 8 of Set 12 | aripuana
# Processing Record 9 of Set 12 | san rafael
# Processing Record 10 of Set 12 | amapa
# Processing Record 11 of Set 12 | port moresby
# Processing Record 12 of Set 12 | rio branco
# Processing Record 13 of Set 12 | manacapuru
# Processing Record 14 of Set 12 | santo antonio do amparo
# Processing Record 15 of Set 12 | gillette
# Processing Record 16 of Set 12 | kailua
# Processing Record 17 of Set 12 | grand gaube
# Processing Record 18 of Set 12 | tel aviv-yafo
# Processing Record 19 of Set 12 | hit
# Processing Record 20 of Set 12 | churapcha
# Processing Record 21 of Set 12 | tigzirt
# Processing Record 22 of Set 12 | neiafu
# Processing Record 23 of Set 12 | bacolod
# Processing Record 24 of Set 12 | sharjah
# Processing Record 25 of Set 12 | san pedro de macoris
# Processing Record 26 of Set 12 | tacarigua
# Processing Record 27 of Set 12 | platteville
# Processing Record 28 of Set 12 | manzhouli
# Processing Record 29 of Set 12 | mackenzie
# Processing Record 30 of Set 12 | russell
# Processing Record 31 of Set 12 | charcas
# Processing Record 32 of Set 12 | najran
# Processing Record 33 of Set 12 | alice town
# Processing Record 34 of Set 12 | chapais
# Processing Record 35 of Set 12 | tomatlan
# Processing Record 36 of Set 12 | choucheng
# City not found. Skipping...
# Processing Record 37 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 12 | maragogi
# Processing Record 39 of Set 12 | khandagayty
# Processing Record 40 of Set 12 | jining
# Processing Record 41 of Set 12 | atchison
# Processing Record 42 of Set 12 | taltal
# Processing Record 43 of Set 12 | ambilobe
# Processing Record 44 of Set 12 | mahibadhoo
# Processing Record 45 of Set 12 | bahia blanca
# Processing Record 46 of Set 12 | bondowoso
# Processing Record 47 of Set 12 | bilokurakyne
# Processing Record 48 of Set 12 | bac lieu
# Processing Record 49 of Set 12 | taoudenni
# Processing Record 50 of Set 12 | kangaatsiaq
# Processing Record 1 of Set 13 | tabou
# Processing Record 2 of Set 13 | conceicao do araguaia
# Processing Record 3 of Set 13 | ligaya
# Processing Record 4 of Set 13 | palmer
# Processing Record 5 of Set 13 | gat
# Processing Record 6 of Set 13 | leatherhead
# Processing Record 7 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 8 of Set 13 | saint-joseph
# Processing Record 9 of Set 13 | knysna
# Processing Record 10 of Set 13 | koumac
# Processing Record 11 of Set 13 | nampula
# Processing Record 12 of Set 13 | tarko-sale
# Processing Record 13 of Set 13 | yatou
# Processing Record 14 of Set 13 | wabash
# Processing Record 15 of Set 13 | gedinne
# Processing Record 16 of Set 13 | amboasary
# Processing Record 17 of Set 13 | gebre guracha
# Processing Record 18 of Set 13 | port-cartier
# Processing Record 19 of Set 13 | tautira
# Processing Record 20 of Set 13 | prince rupert
# Processing Record 21 of Set 13 | kidal
# Processing Record 22 of Set 13 | choctaw
# Processing Record 23 of Set 13 | atasu
# Processing Record 24 of Set 13 | cambados
# Processing Record 25 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 13 | iqaluit
# Processing Record 27 of Set 13 | manaia
# Processing Record 28 of Set 13 | dvinskoy
# Processing Record 29 of Set 13 | kavaratti
# Processing Record 30 of Set 13 | mortka
# Processing Record 31 of Set 13 | ostrovnoy
# Processing Record 32 of Set 13 | mountain home
# Processing Record 33 of Set 13 | hochstadt
# Processing Record 34 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 35 of Set 13 | provost
# Processing Record 36 of Set 13 | iracoubo
# Processing Record 37 of Set 13 | danville
# Processing Record 38 of Set 13 | fereydun kenar
# Processing Record 39 of Set 13 | alanya
# Processing Record 40 of Set 13 | alekseyevsk
# Processing Record 41 of Set 13 | zhezkazgan
# Processing Record 42 of Set 13 | sangar
# Processing Record 43 of Set 13 | moron
# Processing Record 44 of Set 13 | gornopravdinsk
# Processing Record 45 of Set 13 | umm lajj
# Processing Record 46 of Set 13 | acarau
# Processing Record 47 of Set 13 | dingle
# Processing Record 48 of Set 13 | dartford
# Processing Record 49 of Set 13 | arenapolis
# Processing Record 50 of Set 13 | hovd
# Processing Record 1 of Set 14 | laranja da terra
# Processing Record 2 of Set 14 | coos bay
# Processing Record 3 of Set 14 | huazolotitlan
# City not found. Skipping...
# Processing Record 4 of Set 14 | kirakira
# Processing Record 5 of Set 14 | moerai
# Processing Record 6 of Set 14 | aasiaat
# Processing Record 7 of Set 14 | chornobay
# Processing Record 8 of Set 14 | quang ngai
# Processing Record 9 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 14 | pangnirtung
# Processing Record 11 of Set 14 | kabanjahe
# Processing Record 12 of Set 14 | saryozek
# Processing Record 13 of Set 14 | jibuti
# Processing Record 14 of Set 14 | maryborough
# Processing Record 15 of Set 14 | teknaf
# Processing Record 16 of Set 14 | the valley
# Processing Record 17 of Set 14 | arandis
# Processing Record 18 of Set 14 | tura
# Processing Record 19 of Set 14 | verkhoturye
# Processing Record 20 of Set 14 | lompoc
# Processing Record 21 of Set 14 | duz
# City not found. Skipping...
# Processing Record 22 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 14 | rafaela
# Processing Record 24 of Set 14 | suntar
# Processing Record 25 of Set 14 | yeltsovka
# City not found. Skipping...
# Processing Record 26 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 27 of Set 14 | tigil
# Processing Record 28 of Set 14 | tecoanapa
# Processing Record 29 of Set 14 | gisborne
# Processing Record 30 of Set 14 | jasper
# Processing Record 31 of Set 14 | fredericksburg
# Processing Record 32 of Set 14 | montes altos
# Processing Record 33 of Set 14 | champerico
# Processing Record 34 of Set 14 | svetlogorsk
# Processing Record 35 of Set 14 | matagami
# Processing Record 36 of Set 14 | querfurt
# Processing Record 37 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 38 of Set 14 | loandjili
# Processing Record 39 of Set 14 | ketchikan
# Processing Record 40 of Set 14 | aykhal
# Processing Record 41 of Set 14 | clarksburg
# Processing Record 42 of Set 14 | kisanga
# Processing Record 43 of Set 14 | praia da vitoria
# Processing Record 44 of Set 14 | kilindoni
# Processing Record 45 of Set 14 | beloye
# Processing Record 46 of Set 14 | karatau
# Processing Record 47 of Set 14 | juwana
# Processing Record 48 of Set 14 | port augusta
# Processing Record 49 of Set 14 | kudowa-zdroj
# Processing Record 50 of Set 14 | annau
# Processing Record 1 of Set 15 | okakarara
# Processing Record 2 of Set 15 | lubango
# Processing Record 3 of Set 15 | elizabeth city
# Processing Record 4 of Set 15 | kalmunai
# Processing Record 5 of Set 15 | thunder bay
# Processing Record 6 of Set 15 | verkhovazhye
# Processing Record 7 of Set 15 | luz
# Processing Record 8 of Set 15 | motygino
# Processing Record 9 of Set 15 | boende
# Processing Record 10 of Set 15 | valentin gomez farias
# Processing Record 11 of Set 15 | cap malheureux
# Processing Record 12 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 15 | kyra
# Processing Record 14 of Set 15 | novobiryusinskiy
# Processing Record 15 of Set 15 | hambantota
# Processing Record 16 of Set 15 | ormara
# Processing Record 17 of Set 15 | zurrieq
# Processing Record 18 of Set 15 | linxia
# Processing Record 19 of Set 15 | hays
# Processing Record 20 of Set 15 | palu
# Processing Record 21 of Set 15 | banda aceh
# Processing Record 22 of Set 15 | teteles
# Processing Record 23 of Set 15 | santa lucia
# Processing Record 24 of Set 15 | dabakala
# Processing Record 25 of Set 15 | uruguaiana
# Processing Record 26 of Set 15 | chizhou
# Processing Record 27 of Set 15 | ratnagiri
# Processing Record 28 of Set 15 | seka
# Processing Record 29 of Set 15 | fairview
# Processing Record 30 of Set 15 | sheridan
# Processing Record 31 of Set 15 | ler
# Processing Record 32 of Set 15 | tulare
# Processing Record 33 of Set 15 | ziro
# Processing Record 34 of Set 15 | ballina
# Processing Record 35 of Set 15 | dire
# Processing Record 36 of Set 15 | ukiah
# Processing Record 37 of Set 15 | nyrob
# Processing Record 38 of Set 15 | levikha
# Processing Record 39 of Set 15 | vao
# Processing Record 40 of Set 15 | saint anthony
# Processing Record 41 of Set 15 | tazovskiy
# Processing Record 42 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 15 | maningrida
# Processing Record 44 of Set 15 | mezen
# Processing Record 45 of Set 15 | san cristobal
# Processing Record 46 of Set 15 | hualmay
# Processing Record 47 of Set 15 | emba
# Processing Record 48 of Set 15 | ilebo
# Processing Record 49 of Set 15 | ha giang
# Processing Record 50 of Set 15 | magadi
# Processing Record 1 of Set 16 | yambio
# Processing Record 2 of Set 16 | carauari
# Processing Record 3 of Set 16 | doha
# Processing Record 4 of Set 16 | jiwani
# Processing Record 5 of Set 16 | northam
# Processing Record 6 of Set 16 | axim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#create a data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Padang  -0.9492  100.3543     87.85        66          78
# 1  Bambous Virieux -20.3428   57.7575     70.21        73          75
# 2            Vaini -21.2000 -175.2000     78.96        94          40
# 3           Tupiza -21.4500  -65.7167     38.28        19           0
# 4        Busselton -33.6500  115.3333     57.34        72          98
# 5     Ponta Do Sol  32.6667  -17.1000     70.72        87          15
# 6    Bambanglipuro  -7.9500  110.2833     81.30        76          87
# 7           Karwar  14.8000   74.1333     78.53        86          99
# 8       Butaritari   3.0707  172.7902     81.84        75          11
# 9        Cape Town -33.9258   18.4232     56.10        91          78
#
#    Wind Speed Current Description                 Date
# 0        4.36       broken clouds  2022-08-10 04:15:37
# 1       16.11       broken clouds  2022-08-10 04:15:37
# 2        9.22    scattered clouds  2022-08-10 04:15:37
# 3        2.98           clear sky  2022-08-10 04:15:38
# 4       12.53     overcast clouds  2022-08-10 04:15:38
# 5        6.67          few clouds  2022-08-10 04:15:39
# 6       13.42     overcast clouds  2022-08-10 04:15:39
# 7       19.48     overcast clouds  2022-08-10 04:15:39
# 8       13.00          light rain  2022-08-10 04:15:40
# 9        4.00       broken clouds  2022-08-10 04:11:24

# %%
new_column_order = ["City", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City                 Date      Lat       Lng  Max Temp  \
# 0           Padang  2022-08-10 04:15:37  -0.9492  100.3543     87.85
# 1  Bambous Virieux  2022-08-10 04:15:37 -20.3428   57.7575     70.21
# 2            Vaini  2022-08-10 04:15:37 -21.2000 -175.2000     78.96
# 3           Tupiza  2022-08-10 04:15:38 -21.4500  -65.7167     38.28
# 4        Busselton  2022-08-10 04:15:38 -33.6500  115.3333     57.34
# 5     Ponta Do Sol  2022-08-10 04:15:39  32.6667  -17.1000     70.72
# 6    Bambanglipuro  2022-08-10 04:15:39  -7.9500  110.2833     81.30
# 7           Karwar  2022-08-10 04:15:39  14.8000   74.1333     78.53
# 8       Butaritari  2022-08-10 04:15:40   3.0707  172.7902     81.84
# 9        Cape Town  2022-08-10 04:11:24 -33.9258   18.4232     56.10
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        66          78        4.36       broken clouds
# 1        73          75       16.11       broken clouds
# 2        94          40        9.22    scattered clouds
# 3        19           0        2.98           clear sky
# 4        72          98       12.53     overcast clouds
# 5        87          15        6.67          few clouds
# 6        76          87       13.42     overcast clouds
# 7        86          99       19.48     overcast clouds
# 8        75          11       13.00          light rain
# 9        91          78        4.00       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
